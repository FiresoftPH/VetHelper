# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import joblib

# %%
df = pd.read_csv("GN_01_06_23.csv", header=0, names=None)
df.head()
# Out:
#    ID Isolate Number         HN                       Unit Species  \
# 0   1     M2215/2565  5500355.0      หน่วยหอสัตว์ป่วยวิกฤต     Cat
# 1   2        M9/2566  6510301.0      หน่วยหอสัตว์ป่วยวิกฤต     Dog
# 2   3       M22/2566  6513969.0  คลินิกไต/หัวใจ/ต่อมไร้ท่อ     Dog
# 3   4       M27/2565        NaN                        NaN     Cat
# 4   5       M26/2566        NaN                        NaN     Dog
#
#                       Breed     Sex Submitted sample Method of collection  \
# 0                   Persian    Male            urine      catheterization
# 1                    Poodle  Female            urine      Catheterization
# 2                  Bangkaew    Male            urine         cystocenteis
# 3  Domestic Shorthair (DSH)    Male      swab uterus                  NaN
# 4               Mixed breed    Male             swab                  NaN
#
#        Methods  ... Specific resistance phenotype  \
# 0  Vitek/MALDI  ...          Burkholderia cepacia
# 1  Maldi/VITEK  ...              Escherichia coli
# 2  Maldi/VITEK  ...         Klebsiella pneumoniae
# 3  Maldi/VITEK  ...              Escherichia coli
# 4  Vitek/MALDI  ...             Proteus mirabilis
#
#                    Interpretation and recommendation Field1 Field2  \
# 0  -\t จากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 1  -\t จากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 2  - \tจากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 3  - \tการติดเชื้อในมดลูกจัดเป็น medical emergenc...    NaN    NaN
# 4  - เนื่องจากสัตวแพทย์ไม่ได้ระบุชนิดและที่มาของต...    NaN    NaN
#
#   Florfenicol florfenicol_ Sulfamethoxazole/trimethoprim1  \
# 0         NaN          NaN                            NaN
# 1         NaN          NaN                            NaN
# 2         NaN          NaN                            NaN
# 3         NaN          NaN                            NaN
# 4         NaN          NaN                            NaN
#
#   sulfamethoxazole/trimethoprim_1 Specific resistance phenotype1  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   Interpretation and recommendation1
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 62 columns]

# %%
columns_to_drop = ['ID', 'Isolate Number','HN','Unit','Methods','Vitek card lot','Sex',]

df = df.drop(columns=columns_to_drop)
df.columns
# Out:
# Index(['Species', 'Breed', 'Submitted sample', 'Method of collection',
#        'Bacterial species identification', 'Counting (CFU/mL)', 'ESBL',
#        'Ampicillin', 'ampicillin_', 'Amoxicillin/clavulanic acid',
#        'amoxicillin/clavulanic acid_', 'Cephalexin', 'cephalexin_',
#        'Cefalothin', 'cefalothin_', 'Cefpodoxime', 'cefpodoxime_', 'Cefovecin',
#        'cefovecin_', 'Ceftiofur', 'ceftiofur_', 'Imipenem', 'imipenem_',
#        'Amikacin', 'amikacin_', 'Gentamicin', 'gentamicin_', 'Neomycin',
#        'neomycin_', 'Enrofloxacin', 'enrofloxacin_', 'Marbofloxacin',
#        'marbofloxacin_', 'Pradofloxacin', 'pradofloxacin_', 'Doxycycline',
#        'doxycycline_', 'Tetracycline', 'tetracycline_', 'Nitrofurantoin',
#        'nitrofurantoin_', 'Chloramphenicol', 'chloramphenicol_',
#        'Sulfamethoxazole/trimethoprim', 'sulfamethoxazole/trimethoprim_',
#        'Specific resistance phenotype', 'Interpretation and recommendation',
#        'Field1', 'Field2', 'Florfenicol', 'florfenicol_',
#        'Sulfamethoxazole/trimethoprim1', 'sulfamethoxazole/trimethoprim_1',
#        'Specific resistance phenotype1', 'Interpretation and recommendation1'],
#       dtype='object')

# %%
df = pd.get_dummies(df, columns=['Species','Submitted sample', 'Bacterial species identification','Breed'])

# %%
df.head()
# Out:
#   Method of collection Counting (CFU/mL) ESBL Ampicillin ampicillin_  \
# 0      catheterization             >10^5  NaN        NaN         NaN
# 1      Catheterization             >10^5  NEG       >=32           R
# 2         cystocenteis             >10^5  POS       >=32           R
# 3                  NaN               NaN  NEG          8           R
# 4                  NaN               NaN  NaN        <=2           S
#
#   Amoxicillin/clavulanic acid amoxicillin/clavulanic acid_ Cephalexin  \
# 0                         NaN                          NaN        NaN
# 1                           8                            S          8
# 2                        >=32                            R       >=64
# 3                           4                            R          8
# 4                           4                            S         16
#
#   cephalexin_ Cefalothin  ... Breed_Unk Breed_Unknown Breed_Welsh Corgi  \
# 0         NaN        NaN  ...     False         False             False
# 1           S          4  ...     False         False             False
# 2           R       >=64  ...     False         False             False
# 3           R          4  ...     False         False             False
# 4           I        <=2  ...     False         False             False
#
#   Breed_Westie Breed_Yorkshire Terrier Breed_westie terrier Breed_บางแก้ว  \
# 0        False                   False                False         False
# 1        False                   False                False         False
# 2        False                   False                False         False
# 3        False                   False                False         False
# 4        False                   False                False         False
#
#   Breed_ผสม Breed_วิเชียรมาศ Breed_ไทยผสม
# 0     False            False        False
# 1     False            False        False
# 2     False            False        False
# 3     False            False        False
# 4     False            False        False
#
# [5 rows x 264 columns]

# %%
columns = df.columns
columns_med = []

for i in range(0,len(columns)):
    column_name=columns[i]
    column_name.strip()
    if column_name[-1]=="_":
        columns_med.append(column_name)
    
print(columns_med)
# Out:
# ['ampicillin_', 'amoxicillin/clavulanic acid_', 'cephalexin_', 'cefalothin_', 'cefpodoxime_', 'cefovecin_', 'ceftiofur_', 'imipenem_', 'amikacin_', 'gentamicin_', 'neomycin_', 'enrofloxacin_', 'marbofloxacin_', 'pradofloxacin_', 'doxycycline_', 'tetracycline_', 'nitrofurantoin_', 'chloramphenicol_', 'sulfamethoxazole/trimethoprim_', 'florfenicol_']

# %%
featurescol = []

for col in df.columns:
    if "Species" in col or "Submitted sample" in col or "Bacterial species identification" in col:
        featurescol.append(col)

# %%
model_name ="Amikacin_"
path="../2021_Dataset/models/model_"+model_name+"gn.pkl"

model=joblib.load(path)

# %%
for col in columns_med:
    if col == model_na:
        featurescol.append(col)

print(featurescol)
# Out:
# ['Species_Cat', 'Species_Dog', 'Submitted sample_Abdominal cavity', 'Submitted sample_Abscess', 'Submitted sample_Abscess (forehead)', 'Submitted sample_Abscess (thorax)', 'Submitted sample_Bed soore', 'Submitted sample_Bile', 'Submitted sample_Bite wound', 'Submitted sample_Chronic open wound', 'Submitted sample_Chronic wound at Rt aural cavity', 'Submitted sample_Exudate from chin furunculosis/cellulitis', 'Submitted sample_Exudate from wound', 'Submitted sample_Fluid at rt middle ear', 'Submitted sample_Gastric mucosa', 'Submitted sample_Hemoculture', 'Submitted sample_Lt ear exudate', 'Submitted sample_Lt ear swab (otitis)', 'Submitted sample_Lt lumbar area', 'Submitted sample_Lung 23P112R (ส่งตรวจMIC อย่างเดียว)', 'Submitted sample_MIC urine', 'Submitted sample_MIC urine cath', 'Submitted sample_Nasal cavity', 'Submitted sample_Nasal discharge', 'Submitted sample_PG abscess', 'Submitted sample_PG abscess/cyst', 'Submitted sample_PG cyst', 'Submitted sample_Peritoneal effusion', 'Submitted sample_Pleural effusion (pyothorax)', 'Submitted sample_Prostacic fluid (cyst)', 'Submitted sample_Prostate gland swab', 'Submitted sample_Prostatic abscess', 'Submitted sample_Prostatic fluid (cyst)', 'Submitted sample_Pus from Rt fore paw', 'Submitted sample_Rt HL (Surgical site)', 'Submitted sample_Rt auxillary wound', 'Submitted sample_Rt ear', 'Submitted sample_Rt ear swab', 'Submitted sample_Rt middle ear fluid', 'Submitted sample_Rt.ear exudate', 'Submitted sample_Screw and tissue at right tibia', 'Submitted sample_Surgical site (abdominal cavity)', 'Submitted sample_UB mucosa', 'Submitted sample_UB mucosa + calculus', 'Submitted sample_UB mucosa+calculi', 'Submitted sample_UB mucosa+calculus', 'Submitted sample_Ureter + pus in real pelvis', 'Submitted sample_Urine', 'Submitted sample_Wound', 'Submitted sample_abdominal drain', 'Submitted sample_abdominal effusion', 'Submitted sample_abdominal fluid', 'Submitted sample_abdominal swab sx site (after lavage)', 'Submitted sample_abscess', 'Submitted sample_abscess at Rt elbow', 'Submitted sample_abscess wound at Rt base ear', 'Submitted sample_bite wound @ neck', 'Submitted sample_bite wound Rt trunk', 'Submitted sample_chronic wound at Rt FL', 'Submitted sample_conj wound', 'Submitted sample_cystic calculi', 'Submitted sample_dermoid sinus', 'Submitted sample_fistular tract at Rt flank', 'Submitted sample_fluid from lung', 'Submitted sample_folliculitis', 'Submitted sample_hemoculture', 'Submitted sample_hemoculture after no marbo D.2', 'Submitted sample_mammary gland', 'Submitted sample_mass at larynges', 'Submitted sample_nasal cavity', 'Submitted sample_nasal swab', 'Submitted sample_open wd at skin (old G-tube)', 'Submitted sample_open wound', 'Submitted sample_open wound at  ventral abdomen', 'Submitted sample_open wound at Rt elbow', 'Submitted sample_open wound at Rt hip', 'Submitted sample_opened wound', 'Submitted sample_papule', 'Submitted sample_pericadial fluid', 'Submitted sample_pleural effusion', 'Submitted sample_prostatic abscess', 'Submitted sample_prostatic cyst', 'Submitted sample_pus', 'Submitted sample_pus from dorsal tail abscess', 'Submitted sample_salivary mucocele', 'Submitted sample_surgical site', 'Submitted sample_surgical site (wiring of mandible)', 'Submitted sample_surgical site - Rt ear bulla', 'Submitted sample_surgical site @ Lt hip', 'Submitted sample_surgical site at Rt face', 'Submitted sample_surgical wound', 'Submitted sample_surgical wound at perineum', 'Submitted sample_swab', 'Submitted sample_swab left nasal discharge', 'Submitted sample_swab uterus', 'Submitted sample_swab หนองจากแผล', 'Submitted sample_sx wound', 'Submitted sample_sx wound - Surgical site infection (Rt pinnectomy)', 'Submitted sample_urinary bladder (swab)', 'Submitted sample_urine', 'Submitted sample_vaginal swab', 'Submitted sample_wd abscess at rt perineal', 'Submitted sample_wound', 'Submitted sample_wound at Lt FL', 'Submitted sample_wound at Lt Fl', 'Submitted samp ...

# %%
# Perform one-hot encoding
df=df[featurescol]
one_hot_encoded = pd.get_dummies(df['amikacin_'], prefix='S/I/R')

# Concatenate the one-hot encoded columns to the original DataFrame
df = pd.concat([df, one_hot_encoded], axis=1)
df.head()
# Out:
#    Species_Cat  Species_Dog  Submitted sample_Abdominal cavity  \
# 0         True        False                              False
# 1        False         True                              False
# 2        False         True                              False
# 3         True        False                              False
# 4        False         True                              False
#
#    Submitted sample_Abscess  Submitted sample_Abscess (forehead)  \
# 0                     False                                False
# 1                     False                                False
# 2                     False                                False
# 3                     False                                False
# 4                     False                                False
#
#    Submitted sample_Abscess (thorax)  Submitted sample_Bed soore  \
# 0                              False                       False
# 1                              False                       False
# 2                              False                       False
# 3                              False                       False
# 4                              False                       False
#
#    Submitted sample_Bile  Submitted sample_Bite wound  \
# 0                  False                        False
# 1                  False                        False
# 2                  False                        False
# 3                  False                        False
# 4                  False                        False
#
#    Submitted sample_Chronic open wound  ...  \
# 0                                False  ...
# 1                                False  ...
# 2                                False  ...
# 3                                False  ...
# 4                                False  ...
#
#    Bacterial species identification_Salmonella sp  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Bacterial species identification_Serraita nematodiphila  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Bacterial species identification_Serratia nematodiphila  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Bacterial species identification_Suspected Sphingomonas paucimorbilis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Bacterial species identification_Unidentified gram- cocci  amikacin_  \
# 0                                              False                  R
# 1                                              False                  S
# 2                                              False                  R
# 3                                              False                  S
# 4                                              False                  S
#
#    S/I/R_*R  S/I/R_I  S/I/R_R  S/I/R_S
# 0     False    False     True    False
# 1     False    False    False     True
# 2     False    False     True    False
# 3     False    False    False     True
# 4     False    False    False     True
#
# [5 rows x 155 columns]

# %%
#featurescol.remove('amikacin_')

# %%
X_test=df[featurescol]
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[363], line 2
#       1 X_test=df[featurescol]
# ----> 2 y_pred = model.predict(X_test)
#
# File C:\Python311\Lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
#     528 check_is_fitted(self)
# --> 529 X = self._validate_X_predict(X, check_input)
#     530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#
# File C:\Python311\Lib\site-packages\sklearn\tree\_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     force_all_finite = True
# --> 489 X = self._validate_data(
#     490     X,
#     491     dtype=DTYPE,
#     492     accept_sparse="csr",
#     493     reset=False,
#     494     force_all_finite=force_all_finite,
#     495 )
#     496 if issparse(X) and (
#     497     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     498 ):
#     499     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File C:\Python311\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File C:\Python311\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Bacterial species identification_Achromobacter xylosoxidans
# - Bacterial species identification_Acinetobacter baumannii
# - Bacterial species identification_Aeromonas caviae
# - Bacterial species identification_Aeromonas jandaei
# - Bacterial species identification_Burkholderia caepacia
# - ...
# Feature names seen at fit time, yet now missing:
# - S/I/R_amikacin_I
# - S/I/R_amikacin_R
# - S/I/R_amikacin_S
# - S/I/R_amoxicillin/clavulanic acid_I
# - S/I/R_amoxicillin/clavulanic acid_R
# - ...

# %%
data = {'Category': ['A', 'B', 'C', 'A', 'C']}
df = pd.DataFrame(data)

# Perform one-hot encoding
one_hot_encoded = pd.get_dummies(df['Category'], prefix='Category')

# Concatenate the one-hot encoded columns to the original DataFrame
df = pd.concat([df, one_hot_encoded], axis=1)

# Display the result
print(df)
