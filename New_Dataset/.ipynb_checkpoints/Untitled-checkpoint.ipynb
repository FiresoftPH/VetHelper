# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

df = pd.read_csv("GN_01_06_23.csv", header=0, names=None)

# %%
df.head()
# Out:
#    ID Isolate Number         HN                       Unit Species  \
# 0   1     M2215/2565  5500355.0      หน่วยหอสัตว์ป่วยวิกฤต     Cat
# 1   2        M9/2566  6510301.0      หน่วยหอสัตว์ป่วยวิกฤต     Dog
# 2   3       M22/2566  6513969.0  คลินิกไต/หัวใจ/ต่อมไร้ท่อ     Dog
# 3   4       M27/2565        NaN                        NaN     Cat
# 4   5       M26/2566        NaN                        NaN     Dog
#
#                       Breed     Sex Submitted sample Method of collection  \
# 0                   Persian    Male            urine      catheterization
# 1                    Poodle  Female            urine      Catheterization
# 2                  Bangkaew    Male            urine         cystocenteis
# 3  Domestic Shorthair (DSH)    Male      swab uterus                  NaN
# 4               Mixed breed    Male             swab                  NaN
#
#        Methods  ... Specific resistance phenotype  \
# 0  Vitek/MALDI  ...          Burkholderia cepacia
# ...

# %%
columns_to_drop = ['ID', 'Isolate Number','HN','Unit','Methods','Vitek card lot']
to_drop2 = df.columns[-8:]
print(to_drop2)
df = df.drop(columns=columns_to_drop)
# Out:
# Index(['Field1', 'Field2', 'Florfenicol', 'florfenicol_',
#        'Sulfamethoxazole/trimethoprim1', 'sulfamethoxazole/trimethoprim_1',
#        'Specific resistance phenotype1', 'Interpretation and recommendation1'],
#       dtype='object')

# %%
df = df.drop(columns=to_drop2)

# %%
df.head()
# Out:
#   Species                     Breed     Sex Submitted sample  \
# 0     Cat                   Persian    Male            urine
# 1     Dog                    Poodle  Female            urine
# 2     Dog                  Bangkaew    Male            urine
# 3     Cat  Domestic Shorthair (DSH)    Male      swab uterus
# 4     Dog               Mixed breed    Male             swab
#
#   Method of collection Bacterial species identification Counting (CFU/mL)  \
# 0      catheterization             Burkholderia cepacia             >10^5
# 1      Catheterization                 Escherichia coli             >10^5
# 2         cystocenteis            Klebsiella pneumoniae             >10^5
# 3                  NaN                 Escherichia coli               NaN
# 4                  NaN                Proteus mirabilis               NaN
#
#   ESBL Ampicillin ampicillin_  ... Tetracycline tetracycline_ Nitrofurantoin  \
# ...

# %%
all_columns = df.columns

print(all_columns)
# Out:
# Index(['Species', 'Breed', 'Sex', 'Submitted sample', 'Method of collection',
#        'Bacterial species identification', 'Counting (CFU/mL)', 'ESBL',
#        'Ampicillin', 'ampicillin_', 'Amoxicillin/clavulanic acid',
#        'amoxicillin/clavulanic acid_', 'Cephalexin', 'cephalexin_',
#        'Cefalothin', 'cefalothin_', 'Cefpodoxime', 'cefpodoxime_', 'Cefovecin',
#        'cefovecin_', 'Ceftiofur', 'ceftiofur_', 'Imipenem', 'imipenem_',
#        'Amikacin', 'amikacin_', 'Gentamicin', 'gentamicin_', 'Neomycin',
#        'neomycin_', 'Enrofloxacin', 'enrofloxacin_', 'Marbofloxacin',
#        'marbofloxacin_', 'Pradofloxacin', 'pradofloxacin_', 'Doxycycline',
#        'doxycycline_', 'Tetracycline', 'tetracycline_', 'Nitrofurantoin',
#        'nitrofurantoin_', 'Chloramphenicol', 'chloramphenicol_',
#        'Sulfamethoxazole/trimethoprim', 'sulfamethoxazole/trimethoprim_',
#        'Specific resistance phenotype', 'Interpretation and recommendation'],
#       dtype='object')

# %%
medicine_col_to_drop = df.columns[-40:-1]
print(medicine_col_to_drop)
for word in medicine_col_to_drop:
    if word[0].isupper():
        print(word)
        df=df.drop(columns=word)
# Out:
# Index(['Ampicillin', 'ampicillin_', 'Amoxicillin/clavulanic acid',
#        'amoxicillin/clavulanic acid_', 'Cephalexin', 'cephalexin_',
#        'Cefalothin', 'cefalothin_', 'Cefpodoxime', 'cefpodoxime_', 'Cefovecin',
#        'cefovecin_', 'Ceftiofur', 'ceftiofur_', 'Imipenem', 'imipenem_',
#        'Amikacin', 'amikacin_', 'Gentamicin', 'gentamicin_', 'Neomycin',
#        'neomycin_', 'Enrofloxacin', 'enrofloxacin_', 'Marbofloxacin',
#        'marbofloxacin_', 'Pradofloxacin', 'pradofloxacin_', 'Doxycycline',
#        'doxycycline_', 'Tetracycline', 'tetracycline_', 'Nitrofurantoin',
#        'nitrofurantoin_', 'Chloramphenicol', 'chloramphenicol_',
#        'Sulfamethoxazole/trimethoprim', 'sulfamethoxazole/trimethoprim_',
#        'Specific resistance phenotype'],
#       dtype='object')
# Ampicillin
# Amoxicillin/clavulanic acid
# Cephalexin
# Cefalothin
# Cefpodoxime
# Cefovecin
# Ceftiofur
# Imipenem
# Amikacin
# Gentamicin
# Neomycin
# Enrofloxacin
# Marbofloxacin
# ...

# %%
df.head()
# Out:
#   Species                     Breed     Sex Submitted sample  \
# 0     Cat                   Persian    Male            urine
# 1     Dog                    Poodle  Female            urine
# 2     Dog                  Bangkaew    Male            urine
# 3     Cat  Domestic Shorthair (DSH)    Male      swab uterus
# 4     Dog               Mixed breed    Male             swab
#
#   Method of collection Bacterial species identification Counting (CFU/mL)  \
# 0      catheterization             Burkholderia cepacia             >10^5
# 1      Catheterization                 Escherichia coli             >10^5
# 2         cystocenteis            Klebsiella pneumoniae             >10^5
# 3                  NaN                 Escherichia coli               NaN
# 4                  NaN                Proteus mirabilis               NaN
#
#   ESBL ampicillin_ amoxicillin/clavulanic acid_  ... neomycin_ enrofloxacin_  \
# ...

# %%
all_columns = df.columns

print(all_columns)
# Out:
# Index(['Species', 'Breed', 'Sex', 'Submitted sample', 'Method of collection',
#        'Bacterial species identification', 'Counting (CFU/mL)', 'ESBL',
#        'ampicillin_', 'amoxicillin/clavulanic acid_', 'cephalexin_',
#        'cefalothin_', 'cefpodoxime_', 'cefovecin_', 'ceftiofur_', 'imipenem_',
#        'amikacin_', 'gentamicin_', 'neomycin_', 'enrofloxacin_',
#        'marbofloxacin_', 'pradofloxacin_', 'doxycycline_', 'tetracycline_',
#        'nitrofurantoin_', 'chloramphenicol_', 'sulfamethoxazole/trimethoprim_',
#        'Interpretation and recommendation'],
#       dtype='object')

# %%
first_row_values = df.iloc[0]
print(first_row_values)
# Out:
# Species                                                                            Cat
# Breed                                                                          Persian
# Sex                                                                               Male
# Submitted sample                                                                 urine
# Method of collection                                                   catheterization
# Bacterial species identification                                  Burkholderia cepacia
# Counting (CFU/mL)                                                                >10^5
# ESBL                                                                               NaN
# ampicillin_                                                                        NaN
# amoxicillin/clavulanic acid_                                                       NaN
# cephalexin_                                                                        NaN
# ...

# %%
print(df.shape[1])
# Out:
# 28

# %%
empty_array = np.empty((349,19), dtype=str)  # Create an empty NumPy array
medicine_columns_values = df.iloc[1:2, -20:-1].values  # Select last two columns and get values
# empty_array = np.empty(0, dtype=str)
# Add values to the empty array
current_row=0
for i in range(0,df.shape[0]):
    
    empty_array[i] = df.iloc[current_row:current_row+1, -20:-1].values
    current_row=current_row+1
print(empty_array[0:5])
# Out:
# [['n' 'n' 'n' 'n' 'n' 'n' 'n' 'R' 'R' 'R' 'n' 'S' 'S' 'n' 'I' 'R' 'n' 'R'
#   'S']
#  ['R' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'R' 'R' 'I' 'R' 'R' 'S' 'S'
#   'R']
#  ['R' 'R' 'R' 'R' 'R' 'R' 'R' 'I' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#   'R']
#  ['R' 'R' 'R' 'I' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#   'S']
#  ['S' 'S' 'I' 'S' 'S' 'S' 'S' 'I' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'R' 'R' 'S'
#   'S']]

# %%
resistance_without_null_array = []
print(resistance_without_null_array)
# Out:
# []

# %%
for each_array in empty_array:
    if 'n' not in each_array:
        resistance_without_null_array.append(each_array)

# %%
print(np.array(resistance_without_null_array))
data = np.array(resistance_without_null_array)
print(data[100:101])
# Out:
# [['R' 'S' 'S' ... 'S' 'S' 'R']
#  ['R' 'R' 'R' ... 'R' 'R' 'R']
#  ['R' 'R' 'R' ... 'S' 'S' 'S']
#  ...
#  ['S' 'S' 'R' ... 'S' 'S' 'S']
#  ['S' 'S' 'S' ... 'R' 'S' 'S']
#  ['R' 'I' 'R' ... 'R' 'R' 'R']]
# [['S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'R' 'R' 'S' 'S' 'S' 'S'
#   'S']]

# %%
from scipy.stats import mode 
k = 10
  
# Initialize the modes for each cluster 
modes = [] 
for i in range(1,100):
    modes.append(data[i]))


# Initialize the cluster assignments for each data objects 
clusters = np.zeros(data.shape[0], dtype=int) 
clusters_prev = np.zeros(data.shape[0], dtype=int) 
print('lol')  
# Iteratively assign data objects to 
# their clusters and update the cluster modes 
for i in range(10): 
    
    # Assign data objects to the closest cluster 
    for j, object in enumerate(data): 
        distances = np.array([sum(object != mode) for mode in modes]) 
        clusters[j] = np.argmin(distances) 
        
  
    # Update the cluster modes 
    # Update the cluster modes
    # Update the cluster modes
    # for j in range(k):
    #     cluster_data = data[clusters == j]
    #     modes=np.delete(modes, j)
    
        for col in range(data.shape[1]):
            unique_values, counts = np.unique(cluster_data[:, col], return_counts=True)
    
            if len(counts) > 0:
                mode_value = unique_values[np.argmax(counts)]
                modes[j].append(mode_value)
            else:
                # Handle the case when the array is empty (all values are unique)
                # You can set a default value or handle it as needed for your application
                modes[j].append("DefaultMode")
    
    modes = np.array(modes)  # Convert modes list to numpy array
    # Check if the cluster assignments have converged 
    if (clusters == clusters_prev).all(): 
        break
  
    # Store the current cluster assignments 
    clusters_prev = clusters 
    
# Print the cluster assignments for each data point 
print("The cluster assignments for each data object: ", clusters) 
  
# Print the modes for each cluster 
print("Modes for each cluster: ", modes)
# Out:
# lol
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[146], line 36
#      34 if len(counts) > 0:
#      35     mode_value = unique_values[np.argmax(counts)]
# ---> 36     modes[j].append(mode_value)
#      37 else:
#      38     # Handle the case when the array is empty (all values are unique)
#      39     # You can set a default value or handle it as needed for your application
#      40     modes[j].append("DefaultMode")
#
# AttributeError: 'str' object has no attribute 'append'
