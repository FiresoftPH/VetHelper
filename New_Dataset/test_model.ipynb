# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import joblib

# %%
df = pd.read_csv("GN_01_06_23.csv", header=0, names=None)
df.head()
# Out:
#    ID Isolate Number         HN                       Unit Species  \
# 0   1     M2215/2565  5500355.0      หน่วยหอสัตว์ป่วยวิกฤต     Cat
# 1   2        M9/2566  6510301.0      หน่วยหอสัตว์ป่วยวิกฤต     Dog
# 2   3       M22/2566  6513969.0  คลินิกไต/หัวใจ/ต่อมไร้ท่อ     Dog
# 3   4       M27/2565        NaN                        NaN     Cat
# 4   5       M26/2566        NaN                        NaN     Dog
#
#                       Breed     Sex Submitted sample Method of collection  \
# 0                   Persian    Male            urine      catheterization
# 1                    Poodle  Female            urine      Catheterization
# 2                  Bangkaew    Male            urine         cystocenteis
# 3  Domestic Shorthair (DSH)    Male      swab uterus                  NaN
# 4               Mixed breed    Male             swab                  NaN
#
#        Methods  ... Specific resistance phenotype  \
# 0  Vitek/MALDI  ...          Burkholderia cepacia
# 1  Maldi/VITEK  ...              Escherichia coli
# 2  Maldi/VITEK  ...         Klebsiella pneumoniae
# 3  Maldi/VITEK  ...              Escherichia coli
# 4  Vitek/MALDI  ...             Proteus mirabilis
#
#                    Interpretation and recommendation Field1 Field2  \
# 0  -\t จากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 1  -\t จากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 2  - \tจากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 3  - \tการติดเชื้อในมดลูกจัดเป็น medical emergenc...    NaN    NaN
# 4  - เนื่องจากสัตวแพทย์ไม่ได้ระบุชนิดและที่มาของต...    NaN    NaN
#
#   Florfenicol florfenicol_ Sulfamethoxazole/trimethoprim1  \
# 0         NaN          NaN                            NaN
# 1         NaN          NaN                            NaN
# 2         NaN          NaN                            NaN
# 3         NaN          NaN                            NaN
# 4         NaN          NaN                            NaN
#
#   sulfamethoxazole/trimethoprim_1 Specific resistance phenotype1  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   Interpretation and recommendation1
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 62 columns]

# %%
columns_to_drop = ['Breed','ID', 'Isolate Number','HN','Unit','Methods','Vitek card lot','Sex','Method of collection','Counting (CFU/mL)']

df = df.drop(columns=columns_to_drop)
df.columns
# Out:
# Index(['Species', 'Submitted sample', 'Bacterial species identification',
#        'ESBL', 'Ampicillin', 'ampicillin_', 'Amoxicillin/clavulanic acid',
#        'amoxicillin/clavulanic acid_', 'Cephalexin', 'cephalexin_',
#        'Cefalothin', 'cefalothin_', 'Cefpodoxime', 'cefpodoxime_', 'Cefovecin',
#        'cefovecin_', 'Ceftiofur', 'ceftiofur_', 'Imipenem', 'imipenem_',
#        'Amikacin', 'amikacin_', 'Gentamicin', 'gentamicin_', 'Neomycin',
#        'neomycin_', 'Enrofloxacin', 'enrofloxacin_', 'Marbofloxacin',
#        'marbofloxacin_', 'Pradofloxacin', 'pradofloxacin_', 'Doxycycline',
#        'doxycycline_', 'Tetracycline', 'tetracycline_', 'Nitrofurantoin',
#        'nitrofurantoin_', 'Chloramphenicol', 'chloramphenicol_',
#        'Sulfamethoxazole/trimethoprim', 'sulfamethoxazole/trimethoprim_',
#        'Specific resistance phenotype', 'Interpretation and recommendation',
#        'Field1', 'Field2', 'Florfenicol', 'florfenicol_',
#        'Sulfamethoxazole/trimethoprim1', 'sulfamethoxazole/trimethoprim_1',
#        'Specific resistance phenotype1', 'Interpretation and recommendation1'],
#       dtype='object')

# %%
df.rename(columns={'Species': "species"}, inplace=True)
df.rename(columns={'Submitted sample':  "submitted_sample"}, inplace=True)
df.rename(columns={'Bacterial species identification': "bacteria_genus"}, inplace=True)
df['species'] = df['species'].str.lower()

# %%
#df = pd.get_dummies(df, columns=["species", "submitted_sample", "bacteria_genus"])

# %%
df.head()
# Out:
#   species submitted_sample         bacteria_genus ESBL Ampicillin ampicillin_  \
# 0     cat            urine   Burkholderia cepacia  NaN        NaN         NaN
# 1     dog            urine       Escherichia coli  NEG       >=32           R
# 2     dog            urine  Klebsiella pneumoniae  POS       >=32           R
# 3     cat      swab uterus       Escherichia coli  NEG          8           R
# 4     dog             swab      Proteus mirabilis  NaN        <=2           S
#
#   Amoxicillin/clavulanic acid amoxicillin/clavulanic acid_ Cephalexin  \
# 0                         NaN                          NaN        NaN
# 1                           8                            S          8
# 2                        >=32                            R       >=64
# 3                           4                            R          8
# 4                           4                            S         16
#
#   cephalexin_  ... Specific resistance phenotype  \
# 0         NaN  ...          Burkholderia cepacia
# 1           S  ...              Escherichia coli
# 2           R  ...         Klebsiella pneumoniae
# 3           R  ...              Escherichia coli
# 4           I  ...             Proteus mirabilis
#
#                    Interpretation and recommendation Field1 Field2  \
# 0  -\t จากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 1  -\t จากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 2  - \tจากการทำ urine quantitative culture บ่งชี้...    NaN    NaN
# 3  - \tการติดเชื้อในมดลูกจัดเป็น medical emergenc...    NaN    NaN
# 4  - เนื่องจากสัตวแพทย์ไม่ได้ระบุชนิดและที่มาของต...    NaN    NaN
#
#   Florfenicol florfenicol_ Sulfamethoxazole/trimethoprim1  \
# 0         NaN          NaN                            NaN
# 1         NaN          NaN                            NaN
# 2         NaN          NaN                            NaN
# 3         NaN          NaN                            NaN
# 4         NaN          NaN                            NaN
#
#   sulfamethoxazole/trimethoprim_1 Specific resistance phenotype1  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   Interpretation and recommendation1
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 52 columns]

# %%
columns = df.columns
columns_med = []

for i in range(0,len(columns)):
    column_name=columns[i]
    column_name.strip()
    if column_name[-1]=="_":
        columns_med.append(column_name)
    
print(columns_med)
# Out:
# ['ampicillin_', 'amoxicillin/clavulanic acid_', 'cephalexin_', 'cefalothin_', 'cefpodoxime_', 'cefovecin_', 'ceftiofur_', 'imipenem_', 'amikacin_', 'gentamicin_', 'neomycin_', 'enrofloxacin_', 'marbofloxacin_', 'pradofloxacin_', 'doxycycline_', 'tetracycline_', 'nitrofurantoin_', 'chloramphenicol_', 'sulfamethoxazole/trimethoprim_', 'florfenicol_']

# %%
featurescol = []
for col in df.columns:
    if "species" in col or "submitted_sample" in col or "bacteria_genus" in col:
        featurescol.append(col)
print(featurescol)
# Out:
# ['species', 'submitted_sample', 'bacteria_genus']

# %%
model_name ="Amikacin_"
path="../2021_Dataset/models/model_"+model_name+"gn.pkl"

model=joblib.load(path)

# %%
for i in range(0,len(columns_med)):
    columns_med[i]= columns_med[i]
print(columns_med)
# Out:
# ['ampicillin_', 'amoxicillin/clavulanic acid_', 'cephalexin_', 'cefalothin_', 'cefpodoxime_', 'cefovecin_', 'ceftiofur_', 'imipenem_', 'amikacin_', 'gentamicin_', 'neomycin_', 'enrofloxacin_', 'marbofloxacin_', 'pradofloxacin_', 'doxycycline_', 'tetracycline_', 'nitrofurantoin_', 'chloramphenicol_', 'sulfamethoxazole/trimethoprim_', 'florfenicol_']

# %%
for col in columns_med:

    featurescol.append(col)

print(featurescol)
# Out:
# ['species', 'submitted_sample', 'bacteria_genus', 'ampicillin_', 'amoxicillin/clavulanic acid_', 'cephalexin_', 'cefalothin_', 'cefpodoxime_', 'cefovecin_', 'ceftiofur_', 'imipenem_', 'amikacin_', 'gentamicin_', 'neomycin_', 'enrofloxacin_', 'marbofloxacin_', 'pradofloxacin_', 'doxycycline_', 'tetracycline_', 'nitrofurantoin_', 'chloramphenicol_', 'sulfamethoxazole/trimethoprim_', 'florfenicol_']

# %%
# Perform one-hot encoding
df=df[featurescol]
for i in range(0,len(columns_med)):
    df = pd.get_dummies(df,columns=[columns_med[i]],prefix="S/I/R_"+columns_med[i])
# Concatenate the one-hot encoded columns to the original DataFrame

df.head()
# Out:
#   species submitted_sample         bacteria_genus  S/I/R_ampicillin__*R  \
# 0     cat            urine   Burkholderia cepacia                 False
# 1     dog            urine       Escherichia coli                 False
# 2     dog            urine  Klebsiella pneumoniae                 False
# 3     cat      swab uterus       Escherichia coli                 False
# 4     dog             swab      Proteus mirabilis                 False
#
#    S/I/R_ampicillin__R  S/I/R_ampicillin__S  \
# 0                False                False
# 1                 True                False
# 2                 True                False
# 3                 True                False
# 4                False                 True
#
#    S/I/R_amoxicillin/clavulanic acid__*R  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    S/I/R_amoxicillin/clavulanic acid__I  S/I/R_amoxicillin/clavulanic acid__R  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                  True
# 3                                 False                                  True
# 4                                 False                                 False
#
#    S/I/R_amoxicillin/clavulanic acid__S  ...  S/I/R_tetracycline__S  \
# 0                                 False  ...                  False
# 1                                  True  ...                  False
# 2                                 False  ...                  False
# 3                                 False  ...                   True
# 4                                  True  ...                  False
#
#    S/I/R_nitrofurantoin__*R  S/I/R_nitrofurantoin__I  S/I/R_nitrofurantoin__R  \
# 0                     False                    False                    False
# 1                     False                    False                    False
# 2                     False                    False                     True
# 3                     False                    False                    False
# 4                     False                    False                     True
#
#    S/I/R_nitrofurantoin__S  S/I/R_chloramphenicol__I  \
# 0                    False                     False
# 1                     True                     False
# 2                    False                     False
# 3                     True                     False
# 4                    False                     False
#
#    S/I/R_chloramphenicol__R  S/I/R_chloramphenicol__S  \
# 0                      True                     False
# 1                     False                      True
# 2                      True                     False
# 3                     False                      True
# 4                     False                      True
#
#    S/I/R_sulfamethoxazole/trimethoprim__R  \
# 0                                   False
# 1                                    True
# 2                                    True
# 3                                   False
# 4                                   False
#
#    S/I/R_sulfamethoxazole/trimethoprim__S
# 0                                    True
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                    True
#
# [5 rows x 70 columns]

# %%
df = pd.get_dummies(df,columns=['species','submitted_sample', "bacteria_genus"])
df.head()
# Out:
#    S/I/R_ampicillin__*R  S/I/R_ampicillin__R  S/I/R_ampicillin__S  \
# 0                 False                False                False
# 1                 False                 True                False
# 2                 False                 True                False
# 3                 False                 True                False
# 4                 False                False                 True
#
#    S/I/R_amoxicillin/clavulanic acid__*R  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    S/I/R_amoxicillin/clavulanic acid__I  S/I/R_amoxicillin/clavulanic acid__R  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                  True
# 3                                 False                                  True
# 4                                 False                                 False
#
#    S/I/R_amoxicillin/clavulanic acid__S  S/I/R_cephalexin__*R  \
# 0                                 False                 False
# 1                                  True                 False
# 2                                 False                 False
# 3                                 False                 False
# 4                                  True                 False
#
#    S/I/R_cephalexin__I  S/I/R_cephalexin__R  ...  \
# 0                False                False  ...
# 1                False                False  ...
# 2                False                 True  ...
# 3                False                 True  ...
# 4                 True                False  ...
#
#    bacteria_genus_Proteus mirabilis  bacteria_genus_Providencia alcalifaciens  \
# 0                             False                                     False
# 1                             False                                     False
# 2                             False                                     False
# 3                             False                                     False
# 4                              True                                     False
#
#    bacteria_genus_Pseudomonas aeruginosa  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    bacteria_genus_Pseudomonas eruginosa  bacteria_genus_Pseudomonas sp  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
#
#    bacteria_genus_Salmonella sp  bacteria_genus_Serraita nematodiphila  \
# 0                         False                                  False
# 1                         False                                  False
# 2                         False                                  False
# 3                         False                                  False
# 4                         False                                  False
#
#    bacteria_genus_Serratia nematodiphila  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    bacteria_genus_Suspected Sphingomonas paucimorbilis  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    bacteria_genus_Unidentified gram- cocci
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
# [5 rows x 217 columns]

# %%
# for i in range(0,len(featurescol)):
#     word = featurescol[i]
#     if word[-1] == "_":
#         featurescol[i]="S/I/R_"+featurescol[i]

# print(featurescol)

# %%
df.columns
df=df.columns.str.replace("__", "_")

# %%
X_test=df
y_pred = model.predict(X_test)
# Out:
# c:\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[507], line 2
#       1 X_test=df
# ----> 2 y_pred = model.predict(X_test)
#
# File c:\Python311\Lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
#     528 check_is_fitted(self)
# --> 529 X = self._validate_X_predict(X, check_input)
#     530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#
# File c:\Python311\Lib\site-packages\sklearn\tree\_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     force_all_finite = True
# --> 489 X = self._validate_data(
#     490     X,
#     491     dtype=DTYPE,
#     492     accept_sparse="csr",
#     493     reset=False,
#     494     force_all_finite=force_all_finite,
#     495 )
#     496 if issparse(X) and (
#     497     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     498 ):
#     499     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File c:\Python311\Lib\site-packages\sklearn\utils\validation.py:951, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     949         array = xp.astype(array, dtype, copy=False)
#     950     else:
# --> 951         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     952 except ComplexWarning as complex_warning:
#     953     raise ValueError(
#     954         "Complex data not supported\n{}\n".format(array)
#     955     ) from complex_warning
#
# File c:\Python311\Lib\site-packages\sklearn\utils\_array_api.py:521, in _asarray_with_order(array, dtype, order, copy, xp)
#     519     array = numpy.array(array, order=order, dtype=dtype)
#     520 else:
# --> 521     array = numpy.asarray(array, order=order, dtype=dtype)
#     523 # At this point array is a NumPy ndarray. We convert it to an array
#     524 # container that is consistent with the input's namespace.
#     525 return xp.asarray(array)
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:919, in Index.__array__(self, dtype)
#     915 def __array__(self, dtype=None) -> np.ndarray:
#     916     """
#     917     The array interface, return my values.
#     918     """
# --> 919     return np.asarray(self._data, dtype=dtype)
#
# ValueError: could not convert string to float: 'S/I/R_ampicillin_*R'

# %%
data = {'Category': ['A', 'B', 'C', 'A', 'C']}
df = pd.DataFrame(data)

# Perform one-hot encoding
one_hot_encoded = pd.get_dummies(df['Category'], prefix='Category')

# Concatenate the one-hot encoded columns to the original DataFrame
df = pd.concat([df, one_hot_encoded], axis=1)

# Display the result
print(df)

# %%
# Out:
# Original DataFrame:
#   ColumnName
# 0     Value1
# 1     Value2
# 2     Value3
#
# DataFrame with Lowercase Values:
#   ColumnName
# 0     value1
# 1     value2
# 2     value3
